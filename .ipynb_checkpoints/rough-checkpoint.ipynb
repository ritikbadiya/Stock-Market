# %%
import requests

url = "https://yfapi.net/v8/finance/chart/AMZN"

querystring = {"symbols":"AMZN"}

headers = {'x-api-key': "aGceiHvkDqay2EHjG5Gtx4vKRjnIU2wR2HmEvZKF"}

res = requests.request("GET", url, headers=headers )

# %%
res.text
# Out:
# '{"chart":{"result":[{"meta":{"currency":"USD","symbol":"AMZN","exchangeName":"NMS","instrumentType":"EQUITY","firstTradeDate":863703000,"regularMarketTime":1656705604,"gmtoffset":-14400,"timezone":"EDT","exchangeTimezoneName":"America/New_York","regularMarketPrice":109.56,"chartPreviousClose":106.21,"previousClose":106.21,"scale":3,"priceHint":2,"currentTradingPeriod":{"pre":{"timezone":"EDT","start":1656662400,"end":1656682200,"gmtoffset":-14400},"regular":{"timezone":"EDT","start":1656682200,"end":1656705600,"gmtoffset":-14400},"post":{"timezone":"EDT","start":1656705600,"end":1656720000,"gmtoffset":-14400}},"tradingPeriods":[[{"timezone":"EDT","start":1656682200,"end":1656705600,"gmtoffset":-14400}]],"dataGranularity":"1m","range":"1d","validRanges":["1d","5d","1mo","3mo","6mo","1y","2y","5y","10y","ytd","max"]},"timestamp":[1656682200,1656682260,1656682320,1656682380,1656682440,1656682500,1656682560,1656682620,1656682680,1656682740,1656682800,1656682860,1656682920,1656682980,165
# ...
